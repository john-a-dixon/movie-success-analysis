# %% [markdown]
# # **Data Processing**
#
# _John Andrew Dixon_
#
# ---
#
# ##### **Imports**

# %%
# Imports 
import pandas as pd
import numpy as np

# %% [markdown]
# ##### **Data Load**

# %%
# Remote URL to the IMDB data
basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
# Loading the remote data
basics_df = pd.read_csv(basics_url, sep="\t", low_memory=False)
# Verify
basics_df
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9808965  tt9916848  tvEpisode              Episode #3.17
# 9808966  tt9916850  tvEpisode              Episode #3.19
# 9808967  tt9916852  tvEpisode              Episode #3.20
# 9808968  tt9916856      short                   The Wind
# 9808969  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# 2                   Pauvre Pierrot       0      1892      \N              4
# 3                      Un bon bock       0      1892      \N             12
# 4                 Blacksmith Scene       0      1893      \N              1
# ...                            ...     ...       ...     ...            ...
# 9808965              Episode #3.17       0      2010      \N             \N
# 9808966              Episode #3.19       0      2010      \N             \N
# 9808967              Episode #3.20       0      2010      \N             \N
# 9808968                   The Wind       0      2015      \N             27
# 9808969  Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9808965         Action,Drama,Family
# 9808966         Action,Drama,Family
# 9808967         Action,Drama,Family
# 9808968                       Short
# 9808969  Adventure,Animation,Comedy
#
# [9808970 rows x 9 columns]

# %%
# Remote URL to the IMDB data
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
# Loading the remote data
akas_df = pd.read_csv(akas_url, sep="\t", low_memory=False)
# Verify
akas_df
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 35723976  tt9916852         5             Episódio #3.20     PT       pt
# 35723977  tt9916852         6             Episodio #3.20     IT       it
# 35723978  tt9916852         7               एपिसोड #3.20     IN       hi
# 35723979  tt9916856         1                   The Wind     DE       \N
# 35723980  tt9916856         2                   The Wind     \N       \N
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay             \N               0
# 1                  \N  literal title               0
# 2         imdbDisplay             \N               0
# 3         imdbDisplay             \N               0
# 4         imdbDisplay             \N               0
# ...               ...            ...             ...
# 35723976           \N             \N               0
# 35723977           \N             \N               0
# 35723978           \N             \N               0
# 35723979  imdbDisplay             \N               0
# 35723980     original             \N               1
#
# [35723981 rows x 8 columns]

# %%
# Remote URL to the IMDB data
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"
# Loading the remote data
ratings_df = pd.read_csv(ratings_url, sep="\t", low_memory=False)
# Verify
ratings_df
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1966
# 1        tt0000002            5.8       263
# 2        tt0000003            6.5      1808
# 3        tt0000004            5.6       178
# 4        tt0000005            6.2      2607
# ...            ...            ...       ...
# 1305928  tt9916730            8.3        10
# 1305929  tt9916766            7.0        21
# 1305930  tt9916778            7.2        36
# 1305931  tt9916840            8.8         6
# 1305932  tt9916880            8.2         6
#
# [1305933 rows x 3 columns]

# %% [markdown]
# ---
#
# ## **Processing**

# %% [markdown]
# ##### _AKAs_

# %%
# Replace "\N" with np.nan
akas_df.replace({"\\N": np.nan}, inplace=True)

# %%
# Keep only US movies.
akas_df = akas_df.loc[akas_df["region"] == "US", :]
akas_df
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 35723507  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 35723577  tt9916620         1                          The Copeland Case
# 35723666  tt9916702         1              Loving London: The Playground
# 35723709  tt9916756         1                   Pretty Pretty Black Girl
# 35723725  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US      NaN  imdbDisplay                    NaN               0
# 14           US      NaN          NaN  literal English title               0
# 33           US      NaN  imdbDisplay                    NaN               0
# 36           US      NaN  alternative                    NaN               0
# 41           US      NaN  alternative                    NaN               0
# ...         ...      ...          ...                    ...             ...
# 35723507     US      NaN  imdbDisplay                    NaN               0
# 35723577     US      NaN  imdbDisplay                    NaN               0
# 35723666     US      NaN          NaN                    NaN               0
# 35723709     US      NaN  imdbDisplay                    NaN               0
# 35723725     US      NaN  imdbDisplay                    NaN               0
#
# [1432658 rows x 8 columns]

# %% [markdown]
# ##### _Ratings_

# %%
# Replace "\N" with np.nan
ratings_df.replace({"\\N": np.nan}, inplace=True)

# %%
# Keep only US movies

# Get the ratings that have tconst within the akas titleId
only_US = ratings_df["tconst"].isin(akas_df["titleId"])

# Apply the filter
ratings_df = ratings_df.loc[only_US, :]
ratings_df
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1966
# 1        tt0000002            5.8       263
# 4        tt0000005            6.2      2607
# 5        tt0000006            5.2       181
# 6        tt0000007            5.4       816
# ...            ...            ...       ...
# 1305894  tt9916200            8.1       229
# 1305895  tt9916204            8.1       262
# 1305902  tt9916348            8.1        18
# 1305903  tt9916362            6.4      5307
# 1305908  tt9916428            3.8        14
#
# [496709 rows x 3 columns]

# %% [markdown]
# ##### _Basics_

# %%
# Replace "\N" with np.nan
basics_df.replace({"\\N": np.nan}, inplace=True)

# %%
# Eliminate movies that are null for runtimeMinutes
basics_df.dropna(axis=0, subset=["runtimeMinutes"], inplace=True)
basics_df
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 9808920  tt9916754      movie  Chico Albuquerque - Revelações
# 9808926  tt9916766  tvEpisode                  Episode #10.15
# 9808961  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 9808968  tt9916856      short                        The Wind
# 9808969  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle isAdult  startYear  endYear  \
# 0                            Carmencita       0     1894.0      NaN
# 1                Le clown et ses chiens       0     1892.0      NaN
# 2                        Pauvre Pierrot       0     1892.0      NaN
# 3                           Un bon bock       0     1892.0      NaN
# 4                      Blacksmith Scene       0     1893.0      NaN
# ...                                 ...     ...        ...      ...
# 9808920  Chico Albuquerque - Revelações       0     2013.0      NaN
# 9808926                  Episode #10.15       0     2019.0      NaN
# 9808961      Horrid Henry's Comic Caper       0     2014.0      NaN
# 9808968                        The Wind       0     2015.0      NaN
# 9808969       Horrid Henry Knows It All       0     2014.0      NaN
#
#         runtimeMinutes                       genres
# 0                    1            Documentary,Short
# 1                    5              Animation,Short
# 2                    4     Animation,Comedy,Romance
# 3                   12              Animation,Short
# 4                    1                 Comedy,Short
# ...                ...                          ...
# 9808920             49                  Documentary
# 9808926             43  Family,Game-Show,Reality-TV
# 9808961             11   Adventure,Animation,Comedy
# 9808968             27                        Short
# 9808969             10   Adventure,Animation,Comedy
#
# [2890457 rows x 9 columns]

# %%
# Eliminate movies that are null for genre
basics_df.dropna(axis=0, subset=["genres"], inplace=True)
basics_df
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 9808920  tt9916754      movie  Chico Albuquerque - Revelações
# 9808926  tt9916766  tvEpisode                  Episode #10.15
# 9808961  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 9808968  tt9916856      short                        The Wind
# 9808969  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle isAdult  startYear  endYear  \
# 0                            Carmencita       0     1894.0      NaN
# 1                Le clown et ses chiens       0     1892.0      NaN
# 2                        Pauvre Pierrot       0     1892.0      NaN
# 3                           Un bon bock       0     1892.0      NaN
# 4                      Blacksmith Scene       0     1893.0      NaN
# ...                                 ...     ...        ...      ...
# 9808920  Chico Albuquerque - Revelações       0     2013.0      NaN
# 9808926                  Episode #10.15       0     2019.0      NaN
# 9808961      Horrid Henry's Comic Caper       0     2014.0      NaN
# 9808968                        The Wind       0     2015.0      NaN
# 9808969       Horrid Henry Knows It All       0     2014.0      NaN
#
#         runtimeMinutes                       genres
# 0                    1            Documentary,Short
# 1                    5              Animation,Short
# 2                    4     Animation,Comedy,Romance
# 3                   12              Animation,Short
# 4                    1                 Comedy,Short
# ...                ...                          ...
# 9808920             49                  Documentary
# 9808926             43  Family,Game-Show,Reality-TV
# 9808961             11   Adventure,Animation,Comedy
# 9808968             27                        Short
# 9808969             10   Adventure,Animation,Comedy
#
# [2813878 rows x 9 columns]

# %%
# Keep only titleType==Movie

# Create a filter than gets titleType = Movie for all rows
is_movie = basics_df["titleType"] == "movie"

# Apply the filter
basics_df = basics_df.loc[is_movie, :]
basics_df
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# ...            ...       ...
# 9808736  tt9916362     movie
# 9808820  tt9916538     movie
# 9808861  tt9916622     movie
# 9808888  tt9916680     movie
# 9808920  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# ...                                                    ...
# 9808736                                              Coven
# 9808820                                Kuambil Lagi Hatiku
# 9808861        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9808888  De la ilusión al desconcierto: cine colombiano...
# 9808920                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 8                                               Miss Jerry       0     1894.0
# 144                          The Corbett-Fitzsimmons Fight       0     1897.0
# 570                            The Story of the Kelly Gang       0     1906.0
# 587                                      L'enfant prodigue       0     1907.0
# 672                         The Fairylogue and Radio-Plays       0     1908.0
# ...                                                    ...     ...        ...
# 9808736                                           Akelarre       0     2020.0
# 9808820                                Kuambil Lagi Hatiku       0     2019.0
# 9808861        Rodolpho Teóphilo - O Legado de um Pioneiro       0     2015.0
# 9808888  De la ilusión al desconcierto: cine colombiano...       0     2007.0
# 9808920                     Chico Albuquerque - Revelações       0     2013.0
#
#          endYear runtimeMinutes                      genres
# 8            NaN             45                     Romance
# 144          NaN            100      Documentary,News,Sport
# 570          NaN             70  Action,Adventure,Biography
# 587          NaN             90                       Drama
# 672          NaN            120           Adventure,Fantasy
# ...          ...            ...                         ...
# 9808736      NaN             92               Drama,History
# 9808820      NaN            123                       Drama
# 9808861      NaN             57                 Documentary
# 9808888      NaN            100                 Documentary
# 9808920      NaN             49                 Documentary
#
# [381525 rows x 9 columns]

# %%
basics_df["startYear"] = basics_df["startYear"].astype(float)
basics_df["endYear"] = basics_df["endYear"].astype(float)

# %%
# Create a filter that selects all movies with a startYear between 2000 and 2022
between_2000_2022 = (basics_df["startYear"] >= 2000) & (basics_df["startYear"] <= 2022)

# Apply the filter
basics_df = basics_df.loc[between_2000_2022, :]
basics_df
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 76059    tt0077684     movie
# ...            ...       ...
# 9808736  tt9916362     movie
# 9808820  tt9916538     movie
# 9808861  tt9916622     movie
# 9808888  tt9916680     movie
# 9808920  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 76059                    Histórias de Combóios em Portugal
# ...                                                    ...
# 9808736                                              Coven
# 9808820                                Kuambil Lagi Hatiku
# 9808861        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9808888  De la ilusión al desconcierto: cine colombiano...
# 9808920                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0     2021.0
# 34803                                       Kate & Leopold       0     2001.0
# 61116            El tango del viudo y su espejo deformante       0     2020.0
# 67669                           The Other Side of the Wind       0     2018.0
# 76059                    Histórias de Combóios em Portugal       0     2022.0
# ...                                                    ...     ...        ...
# 9808736                                           Akelarre       0     2020.0
# 9808820                                Kuambil Lagi Hatiku       0     2019.0
# 9808861        Rodolpho Teóphilo - O Legado de um Pioneiro       0     2015.0
# 9808888  De la ilusión al desconcierto: cine colombiano...       0     2007.0
# 9808920                     Chico Albuquerque - Revelações       0     2013.0
#
#          endYear runtimeMinutes                  genres
# 13082        NaN             94             Documentary
# 34803        NaN            118  Comedy,Fantasy,Romance
# 61116        NaN             70                   Drama
# 67669        NaN            122                   Drama
# 76059        NaN             46             Documentary
# ...          ...            ...                     ...
# 9808736      NaN             92           Drama,History
# 9808820      NaN            123                   Drama
# 9808861      NaN             57             Documentary
# 9808888      NaN            100             Documentary
# 9808920      NaN             49             Documentary
#
# [223095 rows x 9 columns]

# %%
# Eliminate movies that include "Documentary" in genre

# Create a filter that gets all non-documentary movies
is_not_documentary = ~basics_df["genres"].str.contains("documentary", case=False)

# Apply the filter
basics_df = basics_df.loc[is_not_documentary, :]
basics_df
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 77964    tt0079644     movie
# 86801    tt0088751     movie
# ...            ...       ...
# 9808643  tt9916170     movie
# 9808652  tt9916190     movie
# 9808691  tt9916270     movie
# 9808736  tt9916362     movie
# 9808820  tt9916538     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 77964                                        November 1828
# 86801                                    The Naked Monster
# ...                                                    ...
# 9808643                                      The Rehearsal
# 9808652                                          Safeguard
# 9808691                           Il talento del calabrone
# 9808736                                              Coven
# 9808820                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult  startYear  \
# 34803                               Kate & Leopold       0     2001.0
# 61116    El tango del viudo y su espejo deformante       0     2020.0
# 67669                   The Other Side of the Wind       0     2018.0
# 77964                                November 1828       0     2001.0
# 86801                            The Naked Monster       0     2005.0
# ...                                            ...     ...        ...
# 9808643                                   O Ensaio       0     2019.0
# 9808652                                  Safeguard       0     2020.0
# 9808691                   Il talento del calabrone       0     2020.0
# 9808736                                   Akelarre       0     2020.0
# 9808820                        Kuambil Lagi Hatiku       0     2019.0
#
#          endYear runtimeMinutes                     genres
# 34803        NaN            118     Comedy,Fantasy,Romance
# 61116        NaN             70                      Drama
# 67669        NaN            122                      Drama
# 77964        NaN            140                  Drama,War
# 86801        NaN            100       Comedy,Horror,Sci-Fi
# ...          ...            ...                        ...
# 9808643      NaN             51                      Drama
# 9808652      NaN             95  Action,Adventure,Thriller
# 9808691      NaN             84                   Thriller
# 9808736      NaN             92              Drama,History
# 9808820      NaN            123                      Drama
#
# [147358 rows x 9 columns]

# %%
# Basics: Keep only US movies

# Get the ratings that have tconst within the basics titleId
only_US = basics_df["tconst"].isin(akas_df["titleId"])

# Apply the filter
basics_df = basics_df.loc[only_US, :]
basics_df
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9808108  tt9914942     movie
# 9808503  tt9915872     movie
# 9808643  tt9916170     movie
# 9808652  tt9916190     movie
# 9808736  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9808108                             Life Without Sara Amat
# 9808503                               The Last White Witch
# 9808643                                      The Rehearsal
# 9808652                                          Safeguard
# 9808736                                              Coven
#
#                                      originalTitle isAdult  startYear  \
# 34803                               Kate & Leopold       0     2001.0
# 61116    El tango del viudo y su espejo deformante       0     2020.0
# 67669                   The Other Side of the Wind       0     2018.0
# 86801                            The Naked Monster       0     2005.0
# 93938                         Crime and Punishment       0     2002.0
# ...                                            ...     ...        ...
# 9808108                 La vida sense la Sara Amat       0     2019.0
# 9808503                  My Girlfriend is a Wizard       0     2019.0
# 9808643                                   O Ensaio       0     2019.0
# 9808652                                  Safeguard       0     2020.0
# 9808736                                   Akelarre       0     2020.0
#
#          endYear runtimeMinutes                     genres
# 34803        NaN            118     Comedy,Fantasy,Romance
# 61116        NaN             70                      Drama
# 67669        NaN            122                      Drama
# 86801        NaN            100       Comedy,Horror,Sci-Fi
# 93938        NaN            126                      Drama
# ...          ...            ...                        ...
# 9808108      NaN             74                      Drama
# 9808503      NaN             97       Comedy,Drama,Fantasy
# 9808643      NaN             51                      Drama
# 9808652      NaN             95  Action,Adventure,Thriller
# 9808736      NaN             92              Drama,History
#
# [86554 rows x 9 columns]

# %% [markdown]
# > _**Note:** The stakeholders only want information on movies according to their specifications. So far, only the `basics` data adheres to their specifications. The `akas` and `ratings` data have rows that are not according to their specifications. I'll go ahead and filter out any rows in `akas` and `ratings` that do not align with their specifications by selecting only rows in each table that correspond to the final `basics` data, since it is already according to specifications._

# %%
# Create a filter that gets only AKAs for movies that are according to specs
akas_filter = akas_df["titleId"].isin(basics_df["tconst"])
# Apply the filter
akas_df = akas_df.loc[akas_filter, :]
akas_df
# Out:
#             titleId  ordering  \
# 200628    tt0035423        39
# 200631    tt0035423        41
# 470939    tt0062336         6
# 541299    tt0069049         3
# 728907    tt0088751         1
# ...             ...       ...
# 35721018  tt9914942         5
# 35722696  tt9915872         4
# 35723049  tt9916170         5
# 35723065  tt9916190         6
# 35723237  tt9916362        19
#
#                                                       title region language  \
# 200628                                     Kate and Leopold     US      NaN
# 200631                                       Kate & Leopold     US      NaN
# 470939    The Tango of the Widower and Its Distorting Mi...     US      NaN
# 541299                           The Other Side of the Wind     US      NaN
# 728907                        Attack of the B-Movie Monster     US      NaN
# ...                                                     ...    ...      ...
# 35721018                             Life Without Sara Amat     US      NaN
# 35722696                               The Last White Witch     US      NaN
# 35723049                                      The Rehearsal     US      NaN
# 35723065                                          Safeguard     US      NaN
# 35723237                                              Coven     US      NaN
#
#                 types            attributes isOriginalTitle
# 200628            NaN  alternative spelling               0
# 200631    imdbDisplay                   NaN               0
# 470939    imdbDisplay                   NaN               0
# 541299    imdbDisplay                   NaN               0
# 728907        working                   NaN               0
# ...               ...                   ...             ...
# 35721018  imdbDisplay                   NaN               0
# 35722696  imdbDisplay                   NaN               0
# 35723049  imdbDisplay                   NaN               0
# 35723065  imdbDisplay                   NaN               0
# 35723237  imdbDisplay                   NaN               0
#
# [96318 rows x 8 columns]

# %%
# Create a filter that gets only ratings for movies that are according to specs
ratings_filter = ratings_df["tconst"].isin(basics_df["tconst"])
# Apply the filter
ratings_df = ratings_df.loc[ratings_filter, :]
ratings_df
# Out:
#             tconst  averageRating  numVotes
# 17879    tt0035423            6.4     86556
# 40642    tt0062336            6.4       172
# 46516    tt0069049            6.7      7655
# 63499    tt0088751            5.2       331
# 69806    tt0096056            5.6       835
# ...            ...            ...       ...
# 1305851  tt9914942            6.7       173
# 1305878  tt9915872            7.3         8
# 1305891  tt9916170            7.0         7
# 1305892  tt9916190            3.7       242
# 1305903  tt9916362            6.4      5307
#
# [71414 rows x 3 columns]

# %% [markdown]
# ## **Pre-save check**

# %% [markdown]
# _Before saving, run a final .info() for each of the dataframes to show a summary of how many movies remain and the datatypes of each feature._

# %%
basics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86554 entries, 34803 to 9808736
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          86554 non-null  object
#  1   titleType       86554 non-null  object
#  2   primaryTitle    86554 non-null  object
#  3   originalTitle   86554 non-null  object
#  4   isAdult         86554 non-null  object
#  5   startYear       86554 non-null  float64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  86554 non-null  object
#  8   genres          86554 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 6.6+ MB

# %%
akas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96318 entries, 200628 to 35723237
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   titleId          96318 non-null  object
#  1   ordering         96318 non-null  int64
#  2   title            96318 non-null  object
#  3   region           96318 non-null  object
#  4   language         940 non-null    object
#  5   types            88684 non-null  object
#  6   attributes       4350 non-null   object
#  7   isOriginalTitle  96318 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 6.6+ MB

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71414 entries, 17879 to 1305903
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         71414 non-null  object
#  1   averageRating  71414 non-null  float64
#  2   numVotes       71414 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ MB

# %% [markdown]
# ## **Saving Results**

# %%
# Save each DataFrame to compressed files
basics_df.to_csv("Data/title_basics.csv.gz", compression='gzip',index=False)
ratings_df.to_csv("Data/title_ratings.csv.gz", compression='gzip',index=False)
akas_df.to_csv("Data/title_akas.csv.gz", compression='gzip',index=False)

# %%
# Open saved file and preview again
basics_df = pd.read_csv("Data/title_basics.csv.gz", low_memory=False)
basics_df
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 86549  tt9914942     movie                             Life Without Sara Amat
# 86550  tt9915872     movie                               The Last White Witch
# 86551  tt9916170     movie                                      The Rehearsal
# 86552  tt9916190     movie                                          Safeguard
# 86553  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                     The Other Side of the Wind        0     2018.0      NaN
# 3                              The Naked Monster        0     2005.0      NaN
# 4                           Crime and Punishment        0     2002.0      NaN
# ...                                          ...      ...        ...      ...
# 86549                 La vida sense la Sara Amat        0     2019.0      NaN
# 86550                  My Girlfriend is a Wizard        0     2019.0      NaN
# 86551                                   O Ensaio        0     2019.0      NaN
# 86552                                  Safeguard        0     2020.0      NaN
# 86553                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 86549              74                      Drama
# 86550              97       Comedy,Drama,Fantasy
# 86551              51                      Drama
# 86552              95  Action,Adventure,Thriller
# 86553              92              Drama,History
#
# [86554 rows x 9 columns]

# %%
# Open saved file and preview again
ratings_df = pd.read_csv("Data/title_ratings.csv.gz", low_memory=False)
ratings_df
# Out:
#           tconst  averageRating  numVotes
# 0      tt0035423            6.4     86556
# 1      tt0062336            6.4       172
# 2      tt0069049            6.7      7655
# 3      tt0088751            5.2       331
# 4      tt0096056            5.6       835
# ...          ...            ...       ...
# 71409  tt9914942            6.7       173
# 71410  tt9915872            7.3         8
# 71411  tt9916170            7.0         7
# 71412  tt9916190            3.7       242
# 71413  tt9916362            6.4      5307
#
# [71414 rows x 3 columns]

# %%
# Open saved file and preview again
akas_df = pd.read_csv("Data/title_akas.csv.gz", low_memory=False)
akas_df
# Out:
#          titleId  ordering                                              title  \
# 0      tt0035423        39                                   Kate and Leopold
# 1      tt0035423        41                                     Kate & Leopold
# 2      tt0062336         6  The Tango of the Widower and Its Distorting Mi...
# 3      tt0069049         3                         The Other Side of the Wind
# 4      tt0088751         1                      Attack of the B-Movie Monster
# ...          ...       ...                                                ...
# 96313  tt9914942         5                             Life Without Sara Amat
# 96314  tt9915872         4                               The Last White Witch
# 96315  tt9916170         5                                      The Rehearsal
# 96316  tt9916190         6                                          Safeguard
# 96317  tt9916362        19                                              Coven
#
#       region language        types            attributes  isOriginalTitle
# 0         US      NaN          NaN  alternative spelling                0
# 1         US      NaN  imdbDisplay                   NaN                0
# 2         US      NaN  imdbDisplay                   NaN                0
# 3         US      NaN  imdbDisplay                   NaN                0
# 4         US      NaN      working                   NaN                0
# ...      ...      ...          ...                   ...              ...
# 96313     US      NaN  imdbDisplay                   NaN                0
# 96314     US      NaN  imdbDisplay                   NaN                0
# 96315     US      NaN  imdbDisplay                   NaN                0
# 96316     US      NaN  imdbDisplay                   NaN                0
# 96317     US      NaN  imdbDisplay                   NaN                0
#
# [96318 rows x 8 columns]
