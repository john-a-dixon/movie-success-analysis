# %% [markdown]
# # **Data Processing**
#
# _John Andrew Dixon_
#
# ---
#
# ##### **Imports**

# %%
# Imports 
import pandas as pd
import numpy as np

# %% [markdown]
# ##### **Data Load**

# %%
# Remote URL to the IMDB data
basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
# Loading the remote data
basics_df = pd.read_csv(basics_url, sep="\t", low_memory=False)
# Verify
basics_df
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9800934  tt9916848  tvEpisode              Episode #3.17
# 9800935  tt9916850  tvEpisode              Episode #3.19
# 9800936  tt9916852  tvEpisode              Episode #3.20
# 9800937  tt9916856      short                   The Wind
# 9800938  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# 2                   Pauvre Pierrot       0      1892      \N              4
# 3                      Un bon bock       0      1892      \N             12
# 4                 Blacksmith Scene       0      1893      \N              1
# ...                            ...     ...       ...     ...            ...
# 9800934              Episode #3.17       0      2010      \N             \N
# 9800935              Episode #3.19       0      2010      \N             \N
# 9800936              Episode #3.20       0      2010      \N             \N
# 9800937                   The Wind       0      2015      \N             27
# 9800938  Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9800934         Action,Drama,Family
# 9800935         Action,Drama,Family
# 9800936         Action,Drama,Family
# 9800937                       Short
# 9800938  Adventure,Animation,Comedy
#
# [9800939 rows x 9 columns]

# %%
# Remote URL to the IMDB data
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
# Loading the remote data
akas_df = pd.read_csv(akas_url, sep="\t", low_memory=False)
# Verify
akas_df
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 35704641  tt9916852         5             Episódio #3.20     PT       pt
# 35704642  tt9916852         6             Episodio #3.20     IT       it
# 35704643  tt9916852         7               एपिसोड #3.20     IN       hi
# 35704644  tt9916856         1                   The Wind     DE       \N
# 35704645  tt9916856         2                   The Wind     \N       \N
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay             \N               0
# 1                  \N  literal title               0
# 2         imdbDisplay             \N               0
# 3         imdbDisplay             \N               0
# 4         imdbDisplay             \N               0
# ...               ...            ...             ...
# 35704641           \N             \N               0
# 35704642           \N             \N               0
# 35704643           \N             \N               0
# 35704644  imdbDisplay             \N               0
# 35704645     original             \N               1
#
# [35704646 rows x 8 columns]

# %%
# Remote URL to the IMDB data
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"
# Loading the remote data
ratings_df = pd.read_csv(ratings_url, sep="\t", low_memory=False)
# Verify
ratings_df
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1964
# 1        tt0000002            5.8       263
# 2        tt0000003            6.5      1808
# 3        tt0000004            5.6       178
# 4        tt0000005            6.2      2606
# ...            ...            ...       ...
# 1304124  tt9916730            8.3        10
# 1304125  tt9916766            7.0        21
# 1304126  tt9916778            7.2        36
# 1304127  tt9916840            8.8         6
# 1304128  tt9916880            8.2         6
#
# [1304129 rows x 3 columns]

# %% [markdown]
# ---
#
# ## **Processing**

# %% [markdown]
# ##### _AKAs_

# %%
# Replace "\N" with np.nan
akas_df.replace({"\\N": np.nan}, inplace=True)

# %%
# Keep only US movies.
akas_df = akas_df.loc[akas_df["region"] == "US", :]
akas_df
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 35704172  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 35704242  tt9916620         1                          The Copeland Case
# 35704331  tt9916702         1              Loving London: The Playground
# 35704374  tt9916756         1                   Pretty Pretty Black Girl
# 35704390  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US      NaN  imdbDisplay                    NaN               0
# 14           US      NaN          NaN  literal English title               0
# 33           US      NaN  imdbDisplay                    NaN               0
# 36           US      NaN  alternative                    NaN               0
# 41           US      NaN  alternative                    NaN               0
# ...         ...      ...          ...                    ...             ...
# 35704172     US      NaN  imdbDisplay                    NaN               0
# 35704242     US      NaN  imdbDisplay                    NaN               0
# 35704331     US      NaN          NaN                    NaN               0
# 35704374     US      NaN  imdbDisplay                    NaN               0
# 35704390     US      NaN  imdbDisplay                    NaN               0
#
# [1432167 rows x 8 columns]

# %% [markdown]
# ##### _Ratings_

# %%
# Replace "\N" with np.nan
ratings_df.replace({"\\N": np.nan}, inplace=True)

# %%
# Keep only US movies

# Get the ratings that have tconst within the akas titleId
only_US = ratings_df["tconst"].isin(akas_df["titleId"])

# Apply the filter
ratings_df = ratings_df.loc[only_US, :]
ratings_df
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1964
# 1        tt0000002            5.8       263
# 4        tt0000005            6.2      2606
# 5        tt0000006            5.2       181
# 6        tt0000007            5.4       816
# ...            ...            ...       ...
# 1304090  tt9916200            8.1       229
# 1304091  tt9916204            8.1       262
# 1304098  tt9916348            8.3        18
# 1304099  tt9916362            6.4      5304
# 1304104  tt9916428            3.8        14
#
# [496374 rows x 3 columns]

# %% [markdown]
# ##### _Basics_

# %%
# Replace "\N" with np.nan
basics_df.replace({"\\N": np.nan}, inplace=True)

# %%
# Eliminate movies that are null for runtimeMinutes
basics_df.dropna(axis=0, subset=["runtimeMinutes"], inplace=True)
basics_df
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 9800889  tt9916754      movie  Chico Albuquerque - Revelações
# 9800895  tt9916766  tvEpisode                  Episode #10.15
# 9800930  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 9800937  tt9916856      short                        The Wind
# 9800938  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle isAdult startYear endYear  \
# 0                            Carmencita       0      1894     NaN
# 1                Le clown et ses chiens       0      1892     NaN
# 2                        Pauvre Pierrot       0      1892     NaN
# 3                           Un bon bock       0      1892     NaN
# 4                      Blacksmith Scene       0      1893     NaN
# ...                                 ...     ...       ...     ...
# 9800889  Chico Albuquerque - Revelações       0      2013     NaN
# 9800895                  Episode #10.15       0      2019     NaN
# 9800930      Horrid Henry's Comic Caper       0      2014     NaN
# 9800937                        The Wind       0      2015     NaN
# 9800938       Horrid Henry Knows It All       0      2014     NaN
#
#         runtimeMinutes                       genres
# 0                    1            Documentary,Short
# 1                    5              Animation,Short
# 2                    4     Animation,Comedy,Romance
# 3                   12              Animation,Short
# 4                    1                 Comedy,Short
# ...                ...                          ...
# 9800889             49                  Documentary
# 9800895             43  Family,Game-Show,Reality-TV
# 9800930             11   Adventure,Animation,Comedy
# 9800937             27                        Short
# 9800938             10   Adventure,Animation,Comedy
#
# [2885125 rows x 9 columns]

# %%
# Eliminate movies that are null for genre
basics_df.dropna(axis=0, subset=["genres"], inplace=True)
basics_df
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 9800889  tt9916754      movie  Chico Albuquerque - Revelações
# 9800895  tt9916766  tvEpisode                  Episode #10.15
# 9800930  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 9800937  tt9916856      short                        The Wind
# 9800938  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle isAdult startYear endYear  \
# 0                            Carmencita       0      1894     NaN
# 1                Le clown et ses chiens       0      1892     NaN
# 2                        Pauvre Pierrot       0      1892     NaN
# 3                           Un bon bock       0      1892     NaN
# 4                      Blacksmith Scene       0      1893     NaN
# ...                                 ...     ...       ...     ...
# 9800889  Chico Albuquerque - Revelações       0      2013     NaN
# 9800895                  Episode #10.15       0      2019     NaN
# 9800930      Horrid Henry's Comic Caper       0      2014     NaN
# 9800937                        The Wind       0      2015     NaN
# 9800938       Horrid Henry Knows It All       0      2014     NaN
#
#         runtimeMinutes                       genres
# 0                    1            Documentary,Short
# 1                    5              Animation,Short
# 2                    4     Animation,Comedy,Romance
# 3                   12              Animation,Short
# 4                    1                 Comedy,Short
# ...                ...                          ...
# 9800889             49                  Documentary
# 9800895             43  Family,Game-Show,Reality-TV
# 9800930             11   Adventure,Animation,Comedy
# 9800937             27                        Short
# 9800938             10   Adventure,Animation,Comedy
#
# [2808453 rows x 9 columns]

# %%
# Keep only titleType==Movie

# Create a filter than gets titleType = Movie for all rows
is_movie = basics_df["titleType"] == "movie"

# Apply the filter
basics_df = basics_df.loc[is_movie, :]
basics_df
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# ...            ...       ...
# 9800705  tt9916362     movie
# 9800789  tt9916538     movie
# 9800830  tt9916622     movie
# 9800857  tt9916680     movie
# 9800889  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# ...                                                    ...
# 9800705                                              Coven
# 9800789                                Kuambil Lagi Hatiku
# 9800830        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9800857  De la ilusión al desconcierto: cine colombiano...
# 9800889                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 144                          The Corbett-Fitzsimmons Fight       0      1897
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# 672                         The Fairylogue and Radio-Plays       0      1908
# ...                                                    ...     ...       ...
# 9800705                                           Akelarre       0      2020
# 9800789                                Kuambil Lagi Hatiku       0      2019
# 9800830        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9800857  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9800889                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8           NaN             45                     Romance
# 144         NaN            100      Documentary,News,Sport
# 570         NaN             70  Action,Adventure,Biography
# 587         NaN             90                       Drama
# 672         NaN            120           Adventure,Fantasy
# ...         ...            ...                         ...
# 9800705     NaN             92               Drama,History
# 9800789     NaN            123                       Drama
# 9800830     NaN             57                 Documentary
# 9800857     NaN            100                 Documentary
# 9800889     NaN             49                 Documentary
#
# [381358 rows x 9 columns]

# %%
# Keep startYear 2000-2022

# Create a filter that selects all movies with a startYear between 2000 and 2022
between_2000_2022 = (basics_df["startYear"] >= "2000") & (basics_df["startYear"] <= "2022")
# Apply the filter
basics_df = basics_df.loc[between_2000_2022, :]
basics_df
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 76059    tt0077684     movie
# ...            ...       ...
# 9800705  tt9916362     movie
# 9800789  tt9916538     movie
# 9800830  tt9916622     movie
# 9800857  tt9916680     movie
# 9800889  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 76059                    Histórias de Combóios em Portugal
# ...                                                    ...
# 9800705                                              Coven
# 9800789                                Kuambil Lagi Hatiku
# 9800830        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9800857  De la ilusión al desconcierto: cine colombiano...
# 9800889                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0      2021
# 34803                                       Kate & Leopold       0      2001
# 61116            El tango del viudo y su espejo deformante       0      2020
# 67669                           The Other Side of the Wind       0      2018
# 76059                    Histórias de Combóios em Portugal       0      2022
# ...                                                    ...     ...       ...
# 9800705                                           Akelarre       0      2020
# 9800789                                Kuambil Lagi Hatiku       0      2019
# 9800830        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9800857  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9800889                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                  genres
# 13082       NaN             94             Documentary
# 34803       NaN            118  Comedy,Fantasy,Romance
# 61116       NaN             70                   Drama
# 67669       NaN            122                   Drama
# 76059       NaN             46             Documentary
# ...         ...            ...                     ...
# 9800705     NaN             92           Drama,History
# 9800789     NaN            123                   Drama
# 9800830     NaN             57             Documentary
# 9800857     NaN            100             Documentary
# 9800889     NaN             49             Documentary
#
# [223046 rows x 9 columns]

# %%
# Eliminate movies that include "Documentary" in genre

# Create a filter that gets all non-documentary movies
is_not_documentary = ~basics_df["genres"].str.contains("documentary", case=False)

# Apply the filter
basics_df = basics_df.loc[is_not_documentary, :]
basics_df
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 77964    tt0079644     movie
# 86801    tt0088751     movie
# ...            ...       ...
# 9800612  tt9916170     movie
# 9800621  tt9916190     movie
# 9800660  tt9916270     movie
# 9800705  tt9916362     movie
# 9800789  tt9916538     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 77964                                        November 1828
# 86801                                    The Naked Monster
# ...                                                    ...
# 9800612                                      The Rehearsal
# 9800621                                          Safeguard
# 9800660                           Il talento del calabrone
# 9800705                                              Coven
# 9800789                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult startYear endYear  \
# 34803                               Kate & Leopold       0      2001     NaN
# 61116    El tango del viudo y su espejo deformante       0      2020     NaN
# 67669                   The Other Side of the Wind       0      2018     NaN
# 77964                                November 1828       0      2001     NaN
# 86801                            The Naked Monster       0      2005     NaN
# ...                                            ...     ...       ...     ...
# 9800612                                   O Ensaio       0      2019     NaN
# 9800621                                  Safeguard       0      2020     NaN
# 9800660                   Il talento del calabrone       0      2020     NaN
# 9800705                                   Akelarre       0      2020     NaN
# 9800789                        Kuambil Lagi Hatiku       0      2019     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 77964              140                  Drama,War
# 86801              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9800612             51                      Drama
# 9800621             95  Action,Adventure,Thriller
# 9800660             84                   Thriller
# 9800705             92              Drama,History
# 9800789            123                      Drama
#
# [147329 rows x 9 columns]

# %%
# Basics: Keep only US movies

# Get the ratings that have tconst within the basics titleId
only_US = basics_df["tconst"].isin(akas_df["titleId"])

# Apply the filter
basics_df = basics_df.loc[only_US, :]
basics_df
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9800077  tt9914942     movie
# 9800472  tt9915872     movie
# 9800612  tt9916170     movie
# 9800621  tt9916190     movie
# 9800705  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9800077                             Life Without Sara Amat
# 9800472                               The Last White Witch
# 9800612                                      The Rehearsal
# 9800621                                          Safeguard
# 9800705                                              Coven
#
#                                      originalTitle isAdult startYear endYear  \
# 34803                               Kate & Leopold       0      2001     NaN
# 61116    El tango del viudo y su espejo deformante       0      2020     NaN
# 67669                   The Other Side of the Wind       0      2018     NaN
# 86801                            The Naked Monster       0      2005     NaN
# 93938                         Crime and Punishment       0      2002     NaN
# ...                                            ...     ...       ...     ...
# 9800077                 La vida sense la Sara Amat       0      2019     NaN
# 9800472                  My Girlfriend is a Wizard       0      2019     NaN
# 9800612                                   O Ensaio       0      2019     NaN
# 9800621                                  Safeguard       0      2020     NaN
# 9800705                                   Akelarre       0      2020     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 86801              100       Comedy,Horror,Sci-Fi
# 93938              126                      Drama
# ...                ...                        ...
# 9800077             74                      Drama
# 9800472             97       Comedy,Drama,Fantasy
# 9800612             51                      Drama
# 9800621             95  Action,Adventure,Thriller
# 9800705             92              Drama,History
#
# [86534 rows x 9 columns]

# %% [markdown]
# > _**Note:** The stakeholders only want information on movies according to their specifications. So far, only the `basics` data adheres to their specifictions. The `akas` and `ratings` data have rows that are not according to their specifications. I'll go ahead and filter out any rows in `akas` and `ratings` that do not align with their specifications by selecting only rows in each of the respective tables that correspond to the final `basics` data, since it is already according to specifications._

# %%
# Create a filter that gets only AKAs for movies that are according to specs
akas_filter = akas_df["titleId"].isin(basics_df["tconst"])
# Apply the filter
akas_df = akas_df.loc[akas_filter, :]
akas_df
# Out:
#             titleId  ordering  \
# 200561    tt0035423        39
# 200564    tt0035423        41
# 470787    tt0062336         6
# 541120    tt0069049         3
# 728675    tt0088751         1
# ...             ...       ...
# 35701683  tt9914942         5
# 35703361  tt9915872         4
# 35703714  tt9916170         5
# 35703730  tt9916190         6
# 35703902  tt9916362        19
#
#                                                       title region language  \
# 200561                                     Kate and Leopold     US      NaN
# 200564                                       Kate & Leopold     US      NaN
# 470787    The Tango of the Widower and Its Distorting Mi...     US      NaN
# 541120                           The Other Side of the Wind     US      NaN
# 728675                        Attack of the B-Movie Monster     US      NaN
# ...                                                     ...    ...      ...
# 35701683                             Life Without Sara Amat     US      NaN
# 35703361                               The Last White Witch     US      NaN
# 35703714                                      The Rehearsal     US      NaN
# 35703730                                          Safeguard     US      NaN
# 35703902                                              Coven     US      NaN
#
#                 types            attributes isOriginalTitle
# 200561            NaN  alternative spelling               0
# 200564    imdbDisplay                   NaN               0
# 470787    imdbDisplay                   NaN               0
# 541120    imdbDisplay                   NaN               0
# 728675        working                   NaN               0
# ...               ...                   ...             ...
# 35701683  imdbDisplay                   NaN               0
# 35703361  imdbDisplay                   NaN               0
# 35703714  imdbDisplay                   NaN               0
# 35703730  imdbDisplay                   NaN               0
# 35703902  imdbDisplay                   NaN               0
#
# [96294 rows x 8 columns]

# %%
# Create a filter that gets only ratings for movies that are according to specs
ratings_filter = ratings_df["tconst"].isin(basics_df["tconst"])
# Apply the filter
ratings_df = ratings_df.loc[ratings_filter, :]
ratings_df
# Out:
#             tconst  averageRating  numVotes
# 17879    tt0035423            6.4     86538
# 40641    tt0062336            6.4       171
# 46515    tt0069049            6.7      7649
# 63497    tt0088751            5.2       329
# 69804    tt0096056            5.6       834
# ...            ...            ...       ...
# 1304047  tt9914942            6.7       173
# 1304074  tt9915872            7.3         8
# 1304087  tt9916170            7.0         7
# 1304088  tt9916190            3.7       242
# 1304099  tt9916362            6.4      5304
#
# [71381 rows x 3 columns]

# %% [markdown]
# ## **Pre-save check**

# %% [markdown]
# _Before saving, run a final .info() for each of the dataframes to show a summary of how many movies remain and the datatypes of each feature._

# %%
basics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86534 entries, 34803 to 9800705
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          86534 non-null  object
#  1   titleType       86534 non-null  object
#  2   primaryTitle    86534 non-null  object
#  3   originalTitle   86534 non-null  object
#  4   isAdult         86534 non-null  object
#  5   startYear       86534 non-null  object
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  86534 non-null  object
#  8   genres          86534 non-null  object
# dtypes: object(9)
# memory usage: 6.6+ MB

# %%
akas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96294 entries, 200561 to 35703902
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   titleId          96294 non-null  object
#  1   ordering         96294 non-null  int64
#  2   title            96294 non-null  object
#  3   region           96294 non-null  object
#  4   language         940 non-null    object
#  5   types            88662 non-null  object
#  6   attributes       4350 non-null   object
#  7   isOriginalTitle  96294 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 6.6+ MB

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71381 entries, 17879 to 1304099
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         71381 non-null  object
#  1   averageRating  71381 non-null  float64
#  2   numVotes       71381 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ MB

# %% [markdown]
# ## **Saving Results**

# %%
# Save each DataFrame to compressed files
basics_df.to_csv("Data/title_basics.csv.gz", compression='gzip',index=False)
ratings_df.to_csv("Data/title_ratings.csv.gz", compression='gzip',index=False)
akas_df.to_csv("Data/title_akas.csv.gz", compression='gzip',index=False)

# %%
# Open saved file and preview again
basics_df = pd.read_csv("Data/title_basics.csv.gz", low_memory=False)
basics_df.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
# Open saved file and preview again
ratings_df = pd.read_csv("Data/title_ratings.csv.gz", low_memory=False)
ratings_df.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0035423            6.4     86538
# 1  tt0062336            6.4       171
# 2  tt0069049            6.7      7649
# 3  tt0088751            5.2       329
# 4  tt0096056            5.6       834

# %%
# Open saved file and preview again
akas_df = pd.read_csv("Data/title_akas.csv.gz", low_memory=False)
akas_df.head()
# Out:
#      titleId  ordering                                              title  \
# 0  tt0035423        39                                   Kate and Leopold
# 1  tt0035423        41                                     Kate & Leopold
# 2  tt0062336         6  The Tango of the Widower and Its Distorting Mi...
# 3  tt0069049         3                         The Other Side of the Wind
# 4  tt0088751         1                      Attack of the B-Movie Monster
#
#   region language        types            attributes  isOriginalTitle
# 0     US      NaN          NaN  alternative spelling                0
# 1     US      NaN  imdbDisplay                   NaN                0
# 2     US      NaN  imdbDisplay                   NaN                0
# 3     US      NaN  imdbDisplay                   NaN                0
# 4     US      NaN      working                   NaN                0
